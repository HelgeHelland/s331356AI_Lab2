# %%
import pandas as panda
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
dataset = panda.read_csv('NAS.csv')
dataset
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2003-12-18  19.482599  19.596901  19.025499  19.139799  19.139799
# 1     2003-12-19  19.368299  19.425501  18.282801  18.454201  18.454201
# 2     2003-12-22  18.739901  18.739901  17.997101  18.054300  18.054300
# 3     2003-12-23  17.997101  17.997101  17.368700  17.425800  17.425800
# 4     2003-12-24        NaN        NaN        NaN        NaN        NaN
# ...          ...        ...        ...        ...        ...        ...
# 4248  2020-10-12   0.709000   0.710000   0.650000   0.676800   0.676800
# 4249  2020-10-13   0.676800   0.676800   0.600000   0.600600   0.600600
# 4250  2020-10-14   0.601000   0.640000   0.596200   0.626000   0.626000
# 4251  2020-10-15   0.626000   0.626000   0.585000   0.605000   0.605000
# 4252  2020-10-16   0.605000   0.620000   0.601000   0.610600   0.610600
#
#           Volume
# 0      4978496.0
# 1      1410901.0
# 2       137047.0
# 3       229418.0
# ...

# %%
input = dataset.drop('High',axis='columns')
input = dataset.drop('Open',axis='columns')
input = dataset.drop('Low',axis='columns')
input = dataset.drop('Close',axis='columns')
input = dataset.drop('Adj Close',axis='columns')
input = dataset.drop('Volume',axis='columns')
input.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-ea0c041ec46c> in <module>()
# ----> 1 input = dataset.drop('High',axis='columns')
#       2 input = dataset.drop('Open',axis='columns')
#       3 input = dataset.drop('Low',axis='columns')
#       4 input = dataset.drop('Close',axis='columns')
#       5 input = dataset.drop('High',axis='columns')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4165             level=level,
#    4166             inplace=inplace,
# -> 4167             errors=errors,
#    4168         )
#    4169
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3876         for axis, labels in axes.items():
#    3877             if labels is not None:
# ...
